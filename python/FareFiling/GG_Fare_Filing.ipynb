# %%
import pandas as pd
import pprint

# %%
pp = pprint.PrettyPrinter(indent=2)

input_file = r'.\gg_fare_filing.xlsx'
output_file = r'.\copy_this.xlsx'
orig = 'NYC'
currency = 'USD'

# %%
df_input = pd.read_excel(input_file, sheet_name='input', na_filter=False)
df_input.head()
# Out:
#   dest booking_class season  base_fare direct
# 0  TPE             Y      L       2300
# 1  TPE             B      L       2265
# 2  TPE             C      L       5000      D

# %%
df_cabin_mapping = pd.read_excel(input_file, sheet_name='cabin_mapping')
df_cabin_mapping.head()
# Out:
#   booking_class            cabin
# 0             W  Premium Economy
# 1             U  Premium Economy
# 2             A  Premium Economy
# 3             E  Premium Economy
# 4             Y          Economy

# %%
df_season_mapping = pd.read_excel(input_file, sheet_name='season_mapping')
df_season_mapping.head()
# Out:
#   season season_code
# 0      L           L
# 1     K1           K
# 2     K2           K
# 3     H1           H
# 4     H2           H

# %%
df_input = pd.merge(df_input, df_cabin_mapping, on='booking_class')
df_input = pd.merge(df_input, df_season_mapping, on='season')
df_input.head()
# Out:
#   dest booking_class season  base_fare direct     cabin season_code
# 0  TPE             Y      L       2300          Economy           L
# 1  TPE             B      L       2265          Economy           L
# 2  TPE             C      L       5000      D  Business           L

# %%
df_fare_combination = pd.read_excel(input_file, sheet_name='fare_combination', na_filter=False)
df_fare_combination.head()
# Out:
#   weekend  weekend_surcharge oneway  oneway_multiplier oneway_mapping
# 0       X                  0                       1.0             RT
# 1       W                 80                       1.0             RT
# 2       X                  0      O                0.6             OO
# 3       W                 80      O                0.6             OO

# %%
def gen_fares():
    output = []

    # loop through each input row
    for i, row_input in df_input.iterrows():
        dest = row_input['dest']
        booking_class = row_input['booking_class']
        season = row_input['season']
        season_code = row_input['season_code']
        base_fare = row_input['base_fare']
        direct = row_input['direct']
        cabin = row_input['cabin']
        
        # create different weekend and oneway combinations
        for j, row_fare_combination in df_fare_combination.iterrows():
            weekend = row_fare_combination['weekend']
            oneway = row_fare_combination['oneway']
            weekend_surcharge = row_fare_combination['weekend_surcharge']
            oneway_multiplier = row_fare_combination['oneway_multiplier']

            fare_basis = booking_class + season_code + weekend + 'S' + oneway + direct + 'E'
            fare = (base_fare + weekend_surcharge) * oneway_multiplier
            
            row_output = {
                'orig': orig,
                'dest': dest,
                'fare_basis': fare_basis,
                'booking_class': booking_class,
                'cabin': cabin,
                'ow/rt': oneway,
                'blank1': '',
                'blank2': '',
                'blank3': '',
                'currency': currency,
                'fare': fare
            }
            
            output.append(row_output)
    return output

# %%
pp.pprint(gen_fares())
# Out:
# [ { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'Y',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 2300.0,
#     'fare_basis': 'YLXSE',
#     'orig': 'NYC',
#     'ow/rt': ''},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'Y',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 2380.0,
#     'fare_basis': 'YLWSE',
#     'orig': 'NYC',
#     'ow/rt': ''},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'Y',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 1380.0,
#     'fare_basis': 'YLXSOE',
#     'orig': 'NYC',
#     'ow/rt': 'O'},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'Y',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 1428.0,
#     'fare_basis': 'YLWSOE',
#     'orig': 'NYC',
#     'ow/rt': 'O'},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'B',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 2265.0,
#     'fare_basis': 'BLXSE',
#     'orig': 'NYC',
#     'ow/rt': ''},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'B',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 2345.0,
#     'fare_basis': 'BLWSE',
#     'orig': 'NYC',
#     'ow/rt': ''},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'B',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 1359.0,
#     'fare_basis': 'BLXSOE',
#     'orig': 'NYC',
#     'ow/rt': 'O'},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'B',
#     'cabin': 'Economy',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 1407.0,
#     'fare_basis': 'BLWSOE',
#     'orig': 'NYC',
#     'ow/rt': 'O'},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'C',
#     'cabin': 'Business',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 5000.0,
#     'fare_basis': 'CLXSDE',
#     'orig': 'NYC',
#     'ow/rt': ''},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'C',
#     'cabin': 'Business',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 5080.0,
#     'fare_basis': 'CLWSDE',
#     'orig': 'NYC',
#     'ow/rt': ''},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'C',
#     'cabin': 'Business',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 3000.0,
#     'fare_basis': 'CLXSODE',
#     'orig': 'NYC',
#     'ow/rt': 'O'},
#   { 'blank1': '',
#     'blank2': '',
#     'blank3': '',
#     'booking_class': 'C',
#     'cabin': 'Business',
#     'currency': 'USD',
#     'dest': 'TPE',
#     'fare': 3048.0,
#     'fare_basis': 'CLWSODE',
#     'orig': 'NYC',
#     'ow/rt': 'O'}]

# %%
output = gen_fares()

# %%
columns = [
    'orig', 
    'dest', 
    'fare_basis', 
    'booking_class', 
    'cabin', 
    'ow/rt', 
    'blank1', 
    'blank2', 
    'blank3', 
    'currency', 
    'fare'
]
df_output = pd.DataFrame(columns=columns, data=output)
df_output
# Out:
#    orig dest fare_basis booking_class     cabin ow/rt blank1 blank2 blank3  \
# 0   NYC  TPE      YLXSE             Y   Economy
# 1   NYC  TPE      YLWSE             Y   Economy
# 2   NYC  TPE     YLXSOE             Y   Economy     O
# 3   NYC  TPE     YLWSOE             Y   Economy     O
# 4   NYC  TPE      BLXSE             B   Economy
# 5   NYC  TPE      BLWSE             B   Economy
# 6   NYC  TPE     BLXSOE             B   Economy     O
# 7   NYC  TPE     BLWSOE             B   Economy     O
# 8   NYC  TPE     CLXSDE             C  Business
# 9   NYC  TPE     CLWSDE             C  Business
# 10  NYC  TPE    CLXSODE             C  Business     O
# 11  NYC  TPE    CLWSODE             C  Business     O
#
#    currency    fare
# 0       USD  2300.0
# 1       USD  2380.0
# 2       USD  1380.0
# 3       USD  1428.0
# 4       USD  2265.0
# 5       USD  2345.0
# 6       USD  1359.0
# 7       USD  1407.0
# 8       USD  5000.0
# 9       USD  5080.0
# 10      USD  3000.0
# 11      USD  3048.0

# %%
sheet_name = 'copy_this'
with pd.ExcelWriter(output_file, engine="openpyxl", mode='a') as writer:
    workbook = writer.book
    try:
        workbook.remove(workbook[sheet_name])
    except:
        print('Worksheet does not exist')
    finally:
        df_output.to_excel(writer, sheet_name=sheet_name, index=False)
